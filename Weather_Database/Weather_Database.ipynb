# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrp = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_descrp})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | darab
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | longyearbyen
# Processing Record 5 of Set 1 | semirom
# Processing Record 6 of Set 1 | chokurdakh
# Processing Record 7 of Set 1 | new norfolk
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | lima
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | hithadhoo
# Processing Record 12 of Set 1 | kamenka
# Processing Record 13 of Set 1 | lugovoy
# Processing Record 14 of Set 1 | maragogi
# Processing Record 15 of Set 1 | mount gambier
# Processing Record 16 of Set 1 | astana
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | portland
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | vila velha
# Processing Record 22 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 1 | saskylakh
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | inyonga
# Processing Record 27 of Set 1 | leningradskiy
# Processing Record 28 of Set 1 | cervo
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | shimoni
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | sussex
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | lubango
# Processing Record 37 of Set 1 | chuy
# Processing Record 38 of Set 1 | bambous virieux
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | port hardy
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | sao gabriel da cachoeira
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | hay river
# Processing Record 46 of Set 1 | rocha
# Processing Record 47 of Set 1 | busselton
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | roma
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | shingu
# Processing Record 3 of Set 2 | souillac
# Processing Record 4 of Set 2 | palmer
# Processing Record 5 of Set 2 | ust-omchug
# Processing Record 6 of Set 2 | camargo
# Processing Record 7 of Set 2 | lompoc
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | zhuhai
# Processing Record 10 of Set 2 | kahului
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | cockburn town
# Processing Record 13 of Set 2 | pacific grove
# Processing Record 14 of Set 2 | shimoda
# Processing Record 15 of Set 2 | berdigestyakh
# Processing Record 16 of Set 2 | shitanjing
# Processing Record 17 of Set 2 | dicabisagan
# Processing Record 18 of Set 2 | neiafu
# Processing Record 19 of Set 2 | grand gaube
# Processing Record 20 of Set 2 | paso de los toros
# Processing Record 21 of Set 2 | onalaska
# Processing Record 22 of Set 2 | saint anthony
# Processing Record 23 of Set 2 | esperance
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | adrar
# Processing Record 26 of Set 2 | matara
# Processing Record 27 of Set 2 | bowen
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 30 of Set 2 | guangyuan
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | farah
# Processing Record 33 of Set 2 | la asuncion
# Processing Record 34 of Set 2 | coquimbo
# Processing Record 35 of Set 2 | rutana
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | champerico
# Processing Record 38 of Set 2 | sterling
# Processing Record 39 of Set 2 | tessalit
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | koumac
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 2 | novokayakent
# Processing Record 45 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 2 | bubaque
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | kudahuvadhoo
# Processing Record 50 of Set 2 | ixtapa
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | lucapa
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | fortuna
# Processing Record 6 of Set 3 | sao gotardo
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | port blair
# Processing Record 9 of Set 3 | zhigansk
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | tautira
# Processing Record 12 of Set 3 | alenquer
# Processing Record 13 of Set 3 | aktash
# Processing Record 14 of Set 3 | calvinia
# Processing Record 15 of Set 3 | alpena
# Processing Record 16 of Set 3 | honningsvag
# Processing Record 17 of Set 3 | imbituba
# Processing Record 18 of Set 3 | vaini
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | ovre ardal
# Processing Record 21 of Set 3 | djibo
# Processing Record 22 of Set 3 | jhalawar
# Processing Record 23 of Set 3 | richards bay
# Processing Record 24 of Set 3 | douglas
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | sorland
# Processing Record 27 of Set 3 | bethel
# Processing Record 28 of Set 3 | excelsior springs
# Processing Record 29 of Set 3 | port lincoln
# Processing Record 30 of Set 3 | kiama
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | carauari
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | ponta do sol
# Processing Record 36 of Set 3 | dharchula
# Processing Record 37 of Set 3 | bontang
# Processing Record 38 of Set 3 | thompson
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | pimentel
# Processing Record 41 of Set 3 | staronizhestebliyevskaya
# Processing Record 42 of Set 3 | chingirlau
# Processing Record 43 of Set 3 | bengkulu
# Processing Record 44 of Set 3 | praia
# Processing Record 45 of Set 3 | sinnamary
# Processing Record 46 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 3 | vanderhoof
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | leshukonskoye
# Processing Record 50 of Set 3 | hualmay
# Processing Record 1 of Set 4 | nam phong
# Processing Record 2 of Set 4 | teya
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | kyzyl
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | rawson
# Processing Record 7 of Set 4 | chapais
# Processing Record 8 of Set 4 | fort nelson
# Processing Record 9 of Set 4 | kamina
# Processing Record 10 of Set 4 | nador
# Processing Record 11 of Set 4 | hemsedal
# Processing Record 12 of Set 4 | tezu
# Processing Record 13 of Set 4 | byron bay
# Processing Record 14 of Set 4 | solms
# Processing Record 15 of Set 4 | kapaa
# Processing Record 16 of Set 4 | puerto ayora
# Processing Record 17 of Set 4 | hofn
# Processing Record 18 of Set 4 | samarai
# Processing Record 19 of Set 4 | kemijarvi
# Processing Record 20 of Set 4 | kabardinka
# Processing Record 21 of Set 4 | kangaatsiaq
# Processing Record 22 of Set 4 | beloha
# Processing Record 23 of Set 4 | nalut
# Processing Record 24 of Set 4 | ormond beach
# Processing Record 25 of Set 4 | georgetown
# Processing Record 26 of Set 4 | dareda
# Processing Record 27 of Set 4 | husavik
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | hanumangarh
# Processing Record 30 of Set 4 | sitka
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | jumla
# Processing Record 33 of Set 4 | asau
# Processing Record 34 of Set 4 | dossor
# Processing Record 35 of Set 4 | ambon
# Processing Record 36 of Set 4 | tazovskiy
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | pervomayskoye
# Processing Record 39 of Set 4 | olinda
# Processing Record 40 of Set 4 | kieta
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | puerto escondido
# Processing Record 43 of Set 4 | lagdo
# Processing Record 44 of Set 4 | kirillov
# Processing Record 45 of Set 4 | namatanai
# Processing Record 46 of Set 4 | lagoa
# Processing Record 47 of Set 4 | nanning
# Processing Record 48 of Set 4 | khatanga
# Processing Record 49 of Set 4 | burmakino
# Processing Record 50 of Set 4 | nishihara
# Processing Record 1 of Set 5 | terney
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | mindelo
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | jalu
# Processing Record 6 of Set 5 | inhambane
# Processing Record 7 of Set 5 | srednekolymsk
# Processing Record 8 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 5 | kurilsk
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | atambua
# Processing Record 12 of Set 5 | faanui
# Processing Record 13 of Set 5 | disna
# Processing Record 14 of Set 5 | yulara
# Processing Record 15 of Set 5 | san vicente
# Processing Record 16 of Set 5 | palana
# Processing Record 17 of Set 5 | san quintin
# Processing Record 18 of Set 5 | tarakeswar
# Processing Record 19 of Set 5 | isangel
# Processing Record 20 of Set 5 | mahina
# Processing Record 21 of Set 5 | fare
# Processing Record 22 of Set 5 | aripuana
# Processing Record 23 of Set 5 | aviles
# Processing Record 24 of Set 5 | bathsheba
# Processing Record 25 of Set 5 | klaksvik
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | norman wells
# Processing Record 29 of Set 5 | thunder bay
# Processing Record 30 of Set 5 | surman
# Processing Record 31 of Set 5 | noumea
# Processing Record 32 of Set 5 | vila franca do campo
# Processing Record 33 of Set 5 | bemidji
# Processing Record 34 of Set 5 | bandarbeyla
# Processing Record 35 of Set 5 | havre
# Processing Record 36 of Set 5 | millinocket
# Processing Record 37 of Set 5 | keti bandar
# Processing Record 38 of Set 5 | atherton
# Processing Record 39 of Set 5 | carnarvon
# Processing Record 40 of Set 5 | krasnyy kut
# Processing Record 41 of Set 5 | cabo san lucas
# Processing Record 42 of Set 5 | nizhniy ingash
# Processing Record 43 of Set 5 | bandarban
# Processing Record 44 of Set 5 | erenhot
# Processing Record 45 of Set 5 | chai badan
# Processing Record 46 of Set 5 | amapa
# Processing Record 47 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 48 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 49 of Set 5 | olafsvik
# Processing Record 50 of Set 5 | beni mazar
# Processing Record 1 of Set 6 | itoman
# Processing Record 2 of Set 6 | oistins
# Processing Record 3 of Set 6 | upernavik
# Processing Record 4 of Set 6 | kankakee
# Processing Record 5 of Set 6 | laguna
# Processing Record 6 of Set 6 | warri
# Processing Record 7 of Set 6 | jamame
# Processing Record 8 of Set 6 | chapeco
# Processing Record 9 of Set 6 | havelock
# Processing Record 10 of Set 6 | frolovo
# Processing Record 11 of Set 6 | kathmandu
# Processing Record 12 of Set 6 | sao filipe
# Processing Record 13 of Set 6 | dunedin
# Processing Record 14 of Set 6 | santa isabel
# Processing Record 15 of Set 6 | itamaraca
# Processing Record 16 of Set 6 | altamira
# Processing Record 17 of Set 6 | kochubey
# Processing Record 18 of Set 6 | christchurch
# Processing Record 19 of Set 6 | isla mujeres
# Processing Record 20 of Set 6 | geraldton
# Processing Record 21 of Set 6 | komsomolskiy
# Processing Record 22 of Set 6 | phalaborwa
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | prince rupert
# Processing Record 25 of Set 6 | haines junction
# Processing Record 26 of Set 6 | mezen
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | xuddur
# Processing Record 29 of Set 6 | niquero
# Processing Record 30 of Set 6 | yenagoa
# Processing Record 31 of Set 6 | barra do garcas
# Processing Record 32 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | boa esperanca
# Processing Record 35 of Set 6 | cedar city
# Processing Record 36 of Set 6 | gizo
# Processing Record 37 of Set 6 | asmar
# Processing Record 38 of Set 6 | lapas
# Processing Record 39 of Set 6 | fallon
# Processing Record 40 of Set 6 | griffith
# Processing Record 41 of Set 6 | brekstad
# Processing Record 42 of Set 6 | dovers
# Processing Record 43 of Set 6 | burica
# City not found. Skipping...
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | iqaluit
# Processing Record 46 of Set 6 | mount isa
# Processing Record 47 of Set 6 | bilibino
# Processing Record 48 of Set 6 | cidreira
# Processing Record 49 of Set 6 | harper
# Processing Record 50 of Set 6 | caravelas
# Processing Record 1 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 7 | ayr
# Processing Record 3 of Set 7 | kingman
# Processing Record 4 of Set 7 | victoria
# Processing Record 5 of Set 7 | plettenberg bay
# Processing Record 6 of Set 7 | ledyard
# Processing Record 7 of Set 7 | acajutla
# Processing Record 8 of Set 7 | egvekinot
# Processing Record 9 of Set 7 | svetlyy
# Processing Record 10 of Set 7 | koufovounon
# City not found. Skipping...
# Processing Record 11 of Set 7 | balabac
# Processing Record 12 of Set 7 | panzhihua
# Processing Record 13 of Set 7 | juba
# Processing Record 14 of Set 7 | aksarka
# Processing Record 15 of Set 7 | oktyabrskiy
# Processing Record 16 of Set 7 | altay
# Processing Record 17 of Set 7 | dzilam gonzalez
# Processing Record 18 of Set 7 | nizhniy kuranakh
# Processing Record 19 of Set 7 | caucasia
# Processing Record 20 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 7 | selma
# Processing Record 22 of Set 7 | makakilo city
# Processing Record 23 of Set 7 | oksfjord
# Processing Record 24 of Set 7 | ascension
# Processing Record 25 of Set 7 | sobolevo
# Processing Record 26 of Set 7 | mahibadhoo
# Processing Record 27 of Set 7 | flin flon
# Processing Record 28 of Set 7 | cherskiy
# Processing Record 29 of Set 7 | guerrero negro
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | lorengau
# Processing Record 32 of Set 7 | zhovti vody
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | lianzhou
# Processing Record 35 of Set 7 | montanha
# Processing Record 36 of Set 7 | nouadhibou
# Processing Record 37 of Set 7 | alofi
# Processing Record 38 of Set 7 | pressbaum
# Processing Record 39 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 7 | tuatapere
# Processing Record 41 of Set 7 | havre-saint-pierre
# Processing Record 42 of Set 7 | hue
# Processing Record 43 of Set 7 | masumbwe
# Processing Record 44 of Set 7 | coffs harbour
# Processing Record 45 of Set 7 | port-cartier
# Processing Record 46 of Set 7 | salaverry
# Processing Record 47 of Set 7 | isfana
# Processing Record 48 of Set 7 | khudumelapye
# Processing Record 49 of Set 7 | bushehr
# Processing Record 50 of Set 7 | porto novo
# Processing Record 1 of Set 8 | ulladulla
# Processing Record 2 of Set 8 | slave lake
# Processing Record 3 of Set 8 | acari
# Processing Record 4 of Set 8 | kalemie
# Processing Record 5 of Set 8 | krasnoselkup
# Processing Record 6 of Set 8 | manta
# Processing Record 7 of Set 8 | sabzevar
# Processing Record 8 of Set 8 | bata
# Processing Record 9 of Set 8 | saint-augustin
# Processing Record 10 of Set 8 | nome
# Processing Record 11 of Set 8 | berbera
# Processing Record 12 of Set 8 | ayapel
# Processing Record 13 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 8 | yarada
# Processing Record 15 of Set 8 | saint-pierre
# Processing Record 16 of Set 8 | luba
# Processing Record 17 of Set 8 | constitucion
# Processing Record 18 of Set 8 | aklavik
# Processing Record 19 of Set 8 | moron
# Processing Record 20 of Set 8 | chara
# Processing Record 21 of Set 8 | ilulissat
# Processing Record 22 of Set 8 | labuhan
# Processing Record 23 of Set 8 | lensk
# Processing Record 24 of Set 8 | wegrow
# Processing Record 25 of Set 8 | somerset east
# Processing Record 26 of Set 8 | waitati
# Processing Record 27 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 28 of Set 8 | seoul
# Processing Record 29 of Set 8 | tondano
# Processing Record 30 of Set 8 | baruun-urt
# Processing Record 31 of Set 8 | hamilton
# Processing Record 32 of Set 8 | eyl
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | abapo
# Processing Record 35 of Set 8 | flinders
# Processing Record 36 of Set 8 | mercedes
# Processing Record 37 of Set 8 | cabedelo
# Processing Record 38 of Set 8 | nortelandia
# Processing Record 39 of Set 8 | lamar
# Processing Record 40 of Set 8 | bucerias
# Processing Record 41 of Set 8 | nova era
# Processing Record 42 of Set 8 | ust-barguzin
# Processing Record 43 of Set 8 | astoria
# Processing Record 44 of Set 8 | balakhta
# Processing Record 45 of Set 8 | hanzhong
# Processing Record 46 of Set 8 | muzhi
# Processing Record 47 of Set 8 | boysun
# Processing Record 48 of Set 8 | belaya gora
# Processing Record 49 of Set 8 | kivertsi
# Processing Record 50 of Set 8 | vestmannaeyjar
# Processing Record 1 of Set 9 | vardo
# Processing Record 2 of Set 9 | turiacu
# Processing Record 3 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 4 of Set 9 | faya
# Processing Record 5 of Set 9 | sirjan
# Processing Record 6 of Set 9 | chilca
# Processing Record 7 of Set 9 | pindi gheb
# Processing Record 8 of Set 9 | yuancheng
# Processing Record 9 of Set 9 | kasra
# City not found. Skipping...
# Processing Record 10 of Set 9 | partanna
# Processing Record 11 of Set 9 | thoen
# Processing Record 12 of Set 9 | kulhudhuffushi
# Processing Record 13 of Set 9 | tura
# Processing Record 14 of Set 9 | boa vista
# Processing Record 15 of Set 9 | hirtshals
# Processing Record 16 of Set 9 | ust-shonosha
# Processing Record 17 of Set 9 | lahat
# Processing Record 18 of Set 9 | turukhansk
# Processing Record 19 of Set 9 | pendra
# Processing Record 20 of Set 9 | puerto leguizamo
# Processing Record 21 of Set 9 | meadow lake
# Processing Record 22 of Set 9 | lincoln
# Processing Record 23 of Set 9 | tera
# Processing Record 24 of Set 9 | talnakh
# Processing Record 25 of Set 9 | soyo
# Processing Record 26 of Set 9 | korla
# Processing Record 27 of Set 9 | parabel
# Processing Record 28 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 9 | luderitz
# Processing Record 30 of Set 9 | saint-leu
# Processing Record 31 of Set 9 | sioux lookout
# Processing Record 32 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 33 of Set 9 | paita
# Processing Record 34 of Set 9 | kenora
# Processing Record 35 of Set 9 | pochutla
# Processing Record 36 of Set 9 | manggar
# Processing Record 37 of Set 9 | fairbanks
# Processing Record 38 of Set 9 | qandala
# Processing Record 39 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 40 of Set 9 | ulaanbaatar
# Processing Record 41 of Set 9 | maiduguri
# Processing Record 42 of Set 9 | kapoeta
# Processing Record 43 of Set 9 | trujillo
# Processing Record 44 of Set 9 | numan
# Processing Record 45 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 9 | korba
# Processing Record 47 of Set 9 | hambantota
# Processing Record 48 of Set 9 | sao joao da barra
# Processing Record 49 of Set 9 | torbay
# Processing Record 50 of Set 9 | general salgado
# Processing Record 1 of Set 10 | dawei
# Processing Record 2 of Set 10 | san rafael
# Processing Record 3 of Set 10 | kristiinankaupunki
# Processing Record 4 of Set 10 | naze
# Processing Record 5 of Set 10 | axim
# Processing Record 6 of Set 10 | shangzhi
# Processing Record 7 of Set 10 | paamiut
# Processing Record 8 of Set 10 | ardakan
# Processing Record 9 of Set 10 | pevek
# Processing Record 10 of Set 10 | maceio
# Processing Record 11 of Set 10 | whitefish
# Processing Record 12 of Set 10 | bunia
# Processing Record 13 of Set 10 | fougamou
# Processing Record 14 of Set 10 | zhanaozen
# Processing Record 15 of Set 10 | porteirinha
# Processing Record 16 of Set 10 | warwick
# Processing Record 17 of Set 10 | warrnambool
# Processing Record 18 of Set 10 | khani
# Processing Record 19 of Set 10 | tarko-sale
# Processing Record 20 of Set 10 | lasa
# Processing Record 21 of Set 10 | birao
# Processing Record 22 of Set 10 | kavaratti
# Processing Record 23 of Set 10 | wenatchee
# Processing Record 24 of Set 10 | half moon bay
# Processing Record 25 of Set 10 | magadan
# Processing Record 26 of Set 10 | ballina
# Processing Record 27 of Set 10 | urumqi
# Processing Record 28 of Set 10 | buala
# Processing Record 29 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 10 | ishigaki
# Processing Record 31 of Set 10 | gaya
# Processing Record 32 of Set 10 | suntar
# Processing Record 33 of Set 10 | simao
# Processing Record 34 of Set 10 | coahuayana
# Processing Record 35 of Set 10 | raga
# Processing Record 36 of Set 10 | sungaipenuh
# Processing Record 37 of Set 10 | mount pleasant
# Processing Record 38 of Set 10 | mountain home
# Processing Record 39 of Set 10 | tulum
# Processing Record 40 of Set 10 | hastings
# Processing Record 41 of Set 10 | tvoroyri
# Processing Record 42 of Set 10 | kamalia
# Processing Record 43 of Set 10 | kysyl-syr
# Processing Record 44 of Set 10 | okha
# Processing Record 45 of Set 10 | college place
# Processing Record 46 of Set 10 | nanortalik
# Processing Record 47 of Set 10 | dom pedrito
# Processing Record 48 of Set 10 | port-gentil
# Processing Record 49 of Set 10 | linda
# Processing Record 50 of Set 10 | wajima
# Processing Record 1 of Set 11 | umm lajj
# Processing Record 2 of Set 11 | leh
# Processing Record 3 of Set 11 | sarai naurang
# Processing Record 4 of Set 11 | frei paulo
# Processing Record 5 of Set 11 | orlik
# Processing Record 6 of Set 11 | perth
# Processing Record 7 of Set 11 | taltal
# Processing Record 8 of Set 11 | mayor pablo lagerenza
# Processing Record 9 of Set 11 | msowero
# Processing Record 10 of Set 11 | ewo
# Processing Record 11 of Set 11 | hegra
# Processing Record 12 of Set 11 | mezhdurechensk
# Processing Record 13 of Set 11 | oranjemund
# Processing Record 14 of Set 11 | yar-sale
# Processing Record 15 of Set 11 | namibe
# Processing Record 16 of Set 11 | vila praia de ancora
# Processing Record 17 of Set 11 | westport
# Processing Record 18 of Set 11 | kenai
# Processing Record 19 of Set 11 | de-kastri
# Processing Record 20 of Set 11 | jaumave
# Processing Record 21 of Set 11 | kyzyl-suu
# Processing Record 22 of Set 11 | ostrovnoy
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 25 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 11 | wanning
# Processing Record 27 of Set 11 | najran
# Processing Record 28 of Set 11 | tongchuan
# Processing Record 29 of Set 11 | fort morgan
# Processing Record 30 of Set 11 | perehonivka
# Processing Record 31 of Set 11 | nadym
# Processing Record 32 of Set 11 | vawkavysk
# Processing Record 33 of Set 11 | iskateley
# Processing Record 34 of Set 11 | texarkana
# Processing Record 35 of Set 11 | xai-xai
# Processing Record 36 of Set 11 | ozinki
# Processing Record 37 of Set 11 | vila
# Processing Record 38 of Set 11 | seddon
# Processing Record 39 of Set 11 | karaton
# Processing Record 40 of Set 11 | owando
# Processing Record 41 of Set 11 | along
# Processing Record 42 of Set 11 | ahipara
# Processing Record 43 of Set 11 | itapolis
# Processing Record 44 of Set 11 | angoche
# Processing Record 45 of Set 11 | guapiacu
# Processing Record 46 of Set 11 | lerwick
# Processing Record 47 of Set 11 | meulaboh
# Processing Record 48 of Set 11 | tiarei
# Processing Record 49 of Set 11 | vagur
# Processing Record 50 of Set 11 | pangnirtung
# Processing Record 1 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 2 of Set 12 | washington
# Processing Record 3 of Set 12 | maniitsoq
# Processing Record 4 of Set 12 | coihaique
# Processing Record 5 of Set 12 | rudsar
# Processing Record 6 of Set 12 | athabasca
# Processing Record 7 of Set 12 | la rioja
# Processing Record 8 of Set 12 | bonoua
# Processing Record 9 of Set 12 | sovetskiy
# Processing Record 10 of Set 12 | marawi
# Processing Record 11 of Set 12 | carman
# Processing Record 12 of Set 12 | tabou
# Processing Record 13 of Set 12 | yashkino
# Processing Record 14 of Set 12 | birobidzhan
# Processing Record 15 of Set 12 | arlit
# Processing Record 16 of Set 12 | ambilobe
# Processing Record 17 of Set 12 | itarema
# Processing Record 18 of Set 12 | viedma
# Processing Record 19 of Set 12 | tambura
# Processing Record 20 of Set 12 | barentu
# Processing Record 21 of Set 12 | foz
# Processing Record 22 of Set 12 | chunskiy
# Processing Record 23 of Set 12 | uvira
# Processing Record 24 of Set 12 | nemuro
# Processing Record 25 of Set 12 | marzuq
# Processing Record 26 of Set 12 | lazaro cardenas
# Processing Record 27 of Set 12 | maniwaki
# Processing Record 28 of Set 12 | morgan city
# Processing Record 29 of Set 12 | burgersdorp
# Processing Record 30 of Set 12 | narsaq
# Processing Record 31 of Set 12 | sao sebastiao
# Processing Record 32 of Set 12 | novobirilyussy
# Processing Record 33 of Set 12 | sistranda
# Processing Record 34 of Set 12 | prosyana
# City not found. Skipping...
# Processing Record 35 of Set 12 | umm kaddadah
# Processing Record 36 of Set 12 | ahuimanu
# Processing Record 37 of Set 12 | broken hill
# Processing Record 38 of Set 12 | dingle
# Processing Record 39 of Set 12 | ambikapur
# Processing Record 40 of Set 12 | fukue
# Processing Record 41 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 42 of Set 12 | taoudenni
# Processing Record 43 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 12 | san policarpo
# Processing Record 45 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 12 | turinsk
# Processing Record 47 of Set 12 | antofagasta
# Processing Record 48 of Set 12 | cernosice
# Processing Record 49 of Set 12 | rudbar
# Processing Record 50 of Set 12 | salalah
# Processing Record 1 of Set 13 | kijang
# Processing Record 2 of Set 13 | riohacha
# Processing Record 3 of Set 13 | lufilufi
# Processing Record 4 of Set 13 | riyadh
# Processing Record 5 of Set 13 | emerald
# Processing Record 6 of Set 13 | araouane
# Processing Record 7 of Set 13 | north bend
# Processing Record 8 of Set 13 | amahai
# Processing Record 9 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 13 | otane
# Processing Record 11 of Set 13 | santa rosa
# Processing Record 12 of Set 13 | avera
# Processing Record 13 of Set 13 | kosino
# Processing Record 14 of Set 13 | broome
# Processing Record 15 of Set 13 | haveli
# Processing Record 16 of Set 13 | oildale
# Processing Record 17 of Set 13 | cairns
# Processing Record 18 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 13 | corn island
# Processing Record 20 of Set 13 | loningen
# Processing Record 21 of Set 13 | anderson
# Processing Record 22 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 13 | berlevag
# Processing Record 24 of Set 13 | iberia
# Processing Record 25 of Set 13 | sisimiut
# Processing Record 26 of Set 13 | belmonte
# Processing Record 27 of Set 13 | karoi
# Processing Record 28 of Set 13 | katsuura
# Processing Record 29 of Set 13 | mujiayingzi
# Processing Record 30 of Set 13 | quelimane
# Processing Record 31 of Set 13 | kilkenny
# Processing Record 32 of Set 13 | mnogovershinnyy
# Processing Record 33 of Set 13 | nakhon nayok
# Processing Record 34 of Set 13 | valparaiso
# Processing Record 35 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 36 of Set 13 | quatre cocos
# Processing Record 37 of Set 13 | bud
# Processing Record 38 of Set 13 | achinsk
# Processing Record 39 of Set 13 | polysayevo
# Processing Record 40 of Set 13 | sangar
# Processing Record 41 of Set 13 | camana
# Processing Record 42 of Set 13 | marystown
# Processing Record 43 of Set 13 | suleja
# Processing Record 44 of Set 13 | sarakhs
# Processing Record 45 of Set 13 | mutis
# Processing Record 46 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 47 of Set 13 | la ronge
# Processing Record 48 of Set 13 | velikiy ustyug
# Processing Record 49 of Set 13 | doha
# Processing Record 50 of Set 13 | balkhash
# Processing Record 1 of Set 14 | liverpool
# Processing Record 2 of Set 14 | coromandel
# Processing Record 3 of Set 14 | gat
# Processing Record 4 of Set 14 | kemi
# Processing Record 5 of Set 14 | hobyo
# Processing Record 6 of Set 14 | tilichiki
# Processing Record 7 of Set 14 | pisco
# Processing Record 8 of Set 14 | ohara
# Processing Record 9 of Set 14 | diffa
# Processing Record 10 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | durango
# Processing Record 12 of Set 14 | chihuahua
# Processing Record 13 of Set 14 | adre
# Processing Record 14 of Set 14 | vangaindrano
# Processing Record 15 of Set 14 | winchester
# Processing Record 16 of Set 14 | santa cruz del sur
# Processing Record 17 of Set 14 | salinas
# Processing Record 18 of Set 14 | zaysan
# Processing Record 19 of Set 14 | damietta
# Processing Record 20 of Set 14 | lira
# Processing Record 21 of Set 14 | nagato
# Processing Record 22 of Set 14 | acurenam
# Processing Record 23 of Set 14 | nuevo progreso
# Processing Record 24 of Set 14 | buraydah
# Processing Record 25 of Set 14 | jaramana
# City not found. Skipping...
# Processing Record 26 of Set 14 | mackay
# Processing Record 27 of Set 14 | alta floresta
# Processing Record 28 of Set 14 | rio grande
# Processing Record 29 of Set 14 | nanga eboko
# Processing Record 30 of Set 14 | mamlyutka
# Processing Record 31 of Set 14 | tigil
# Processing Record 32 of Set 14 | visby
# Processing Record 33 of Set 14 | port macquarie
# Processing Record 34 of Set 14 | thanatpin
# Processing Record 35 of Set 14 | san patricio
# Processing Record 36 of Set 14 | cartagena del chaira
# Processing Record 37 of Set 14 | pran buri
# Processing Record 38 of Set 14 | tres marias
# Processing Record 39 of Set 14 | remiremont
# Processing Record 40 of Set 14 | banda aceh
# Processing Record 41 of Set 14 | minot
# Processing Record 42 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 43 of Set 14 | ramgarh
# Processing Record 44 of Set 14 | baykit
# Processing Record 45 of Set 14 | bacolod
# Processing Record 46 of Set 14 | alice springs
# Processing Record 47 of Set 14 | jagtial
# Processing Record 48 of Set 14 | quesnel
# Processing Record 49 of Set 14 | glendive
# Processing Record 50 of Set 14 | swan river
# Processing Record 1 of Set 15 | villa carlos paz
# Processing Record 2 of Set 15 | ostersund
# Processing Record 3 of Set 15 | roald
# Processing Record 4 of Set 15 | praia da vitoria
# Processing Record 5 of Set 15 | kichera
# Processing Record 6 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 7 of Set 15 | bar harbor
# Processing Record 8 of Set 15 | muli
# Processing Record 9 of Set 15 | ryazanovskiy
# Processing Record 10 of Set 15 | pomerode
# Processing Record 11 of Set 15 | somerset
# Processing Record 12 of Set 15 | markala
# Processing Record 13 of Set 15 | margate
# Processing Record 14 of Set 15 | kirensk
# Processing Record 15 of Set 15 | namwala
# Processing Record 16 of Set 15 | desna
# Processing Record 17 of Set 15 | pascagoula
# Processing Record 18 of Set 15 | lodja
# Processing Record 19 of Set 15 | yerbogachen
# Processing Record 20 of Set 15 | toguchin
# Processing Record 21 of Set 15 | ketchikan
# Processing Record 22 of Set 15 | wufeng
# Processing Record 23 of Set 15 | novaya lyalya
# Processing Record 24 of Set 15 | galle
# Processing Record 25 of Set 15 | karratha
# Processing Record 26 of Set 15 | kita
# Processing Record 27 of Set 15 | padang
# Processing Record 28 of Set 15 | guarapari
# Processing Record 29 of Set 15 | jupiter
# Processing Record 30 of Set 15 | guapore
# Processing Record 31 of Set 15 | homer
# Processing Record 32 of Set 15 | seguela
# Processing Record 33 of Set 15 | cururupu
# Processing Record 34 of Set 15 | burnie
# Processing Record 35 of Set 15 | qasigiannguit
# Processing Record 36 of Set 15 | hirara
# Processing Record 37 of Set 15 | houma
# Processing Record 38 of Set 15 | irituia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     76.60        73          24
# 1         Darab  28.7519   54.5444     58.55        43           0
# 2  Longyearbyen  78.2186   15.6401     12.04        67          40
# 3       Semirom  31.4167   51.5667     37.60        76         100
# 4    Chokurdakh  70.6333  147.9167    -31.68        99         100
# 5   New Norfolk -42.7826  147.0587     67.50        38           0
# 6        Castro -24.7911  -50.0119     63.73        75           1
# 7          Lima -12.0432  -77.0282     64.65        77          20
# 8        Albany  42.6001  -73.9662     27.25        66           5
# 9     Hithadhoo  -0.6000   73.0833     81.68        71          97
#
#    Wind Speed Country Current Description
# 0       15.68      PF          few clouds
# 1        2.51      IR           clear sky
# 2       28.77      SJ    scattered clouds
# 3        1.23      IR     overcast clouds
# 4        0.58      RU     overcast clouds
# 5        2.71      AU           clear sky
# 6        0.78      BR           clear sky
# 7       12.66      PE          few clouds
# 8        8.95      US           clear sky
# 9       17.20      MV     overcast clouds

# %%
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df =city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea      PF -23.1203 -134.9692     76.60        73          24
# 1         Darab      IR  28.7519   54.5444     58.55        43           0
# 2  Longyearbyen      SJ  78.2186   15.6401     12.04        67          40
# 3       Semirom      IR  31.4167   51.5667     37.60        76         100
# 4    Chokurdakh      RU  70.6333  147.9167    -31.68        99         100
#
#    Wind Speed Current Description
# 0       15.68          few clouds
# 1        2.51           clear sky
# 2       28.77    scattered clouds
# 3        1.23     overcast clouds
# 4        0.58     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
